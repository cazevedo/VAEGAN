# %%
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv("results_credit.csv")
df.replace("GAINCredit", 'GAIN', inplace=True)

df.columns = ["Approach", "Missing Data Mechanism", "Missing Ratio", 'n', 'NRMSE', 'R2', 'MSE']

# %%
ax = sns.catplot(x="Missing Ratio", y='NRMSE', hue='Approach', hue_order=['GAIN', 'MICE', 'MissForest', 'MeanImputation', 'MostFrequent'],col='Missing Data Mechanism', data=df, kind='box')
ax.savefig('Credit_NRMSE.png')

# %%
ax = sns.catplot(x="Missing Ratio", y='R2', hue='Approach', hue_order=['GAIN', 'MICE', 'MissForest', 'MeanImputation', 'MostFrequent'],col='Missing Data Mechanism', data=df, kind='box')
ax.savefig('Credit_R2.png')

# %%
ax = sns.catplot(x="Missing Ratio", y='MSE', hue='Approach', hue_order=['GAIN', 'MICE', 'MissForest', 'MeanImputation', 'MostFrequent'],col='Missing Data Mechanism', data=df, kind='box')
ax.savefig('Credit_MSE.png')
